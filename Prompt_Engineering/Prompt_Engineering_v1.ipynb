# %% [markdown]
# <a href="https://colab.research.google.com/github/claudio1975/Medium-blog/blob/master/Prompt_Engineering/Prompt_Engineering_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers &> /dev/null

# %%
# !pip install langchain &>/dev/null

# %%
from langchain.prompts import ChatPromptTemplate
from langchain.schema import AIMessage, HumanMessage, SystemMessage
from transformers import AutoModelForCausalLM, AutoTokenizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import torch
import collections

# %%
# Load tokenizer and model
checkpoint = "HuggingFaceTB/SmolLM2-1.7B-Instruct"
device = "cuda" if torch.cuda.is_available() else "cpu"

tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForCausalLM.from_pretrained(checkpoint).to(device)
# Out:
# tokenizer_config.json:   0%|          | 0.00/3.76k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/801k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.10M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/655 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/792 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.42G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]

# %%
# Function to process the chat with mode selection for reasoning
def generate_response(system_message, user_message, mode='shot'):
    # Construct conversation text based on the mode
    if mode == 'chain-of-thought':
        conversation = (f"{system_message.content}\n"
                        f"User: {user_message.content}\n"
                        f"AI: Let's break it down step-by-step:\n")
    else:  # Defaults to zero-one-few-shot
        conversation = f"{system_message.content}\nUser: {user_message.content}\nAI:"

    # Tokenize input and create attention mask
    tokens = tokenizer(conversation, return_tensors="pt")
    inputs = tokens['input_ids'].to(device)
    attention_mask = tokens['attention_mask'].to(device)

    # Generate AI's response
    # Adjust generation settings when doing CoT
    if mode == 'chain-of-thought':
        temperature = 0.3
        max_new_tokens = 350
    else:  # zero-shot
        temperature = 0.1
        max_new_tokens = 350

    outputs = model.generate(inputs,
                             attention_mask=attention_mask,
                             max_new_tokens=max_new_tokens,
                             temperature=temperature,
                             top_p=0.9, do_sample=True)

    # Decode and return the AIMessage
    output_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    response_text = output_text.split('AI:')[-1].strip()  # Capture what's generated after 'AI:'
    return AIMessage(content=response_text)

# %% [markdown]
# ### Zero-Shot Prompting

# %%
# Define initial messages
system_message = SystemMessage(content="You are a machine learning engineer. Give an help in coding")
user_message = HumanMessage(content="write python code for a synthetic daily time series of stock prices from 01/2024 to 06/2024")

# Generate response
ai_response = generate_response(system_message, user_message, mode='shot')
print(ai_response.content)
# Out:
# Here's a simple Python code snippet using the pandas library to generate a synthetic daily time series of stock prices from January 2024 to June 2024:
#
# ```python
# import pandas as pd
# import numpy as np
#
# # Set the start and end dates
# start_date = '2024-01-01'
# end_date = '2024-06-30'
#
# # Create a pandas DataFrame with random stock prices
# df = pd.DataFrame({
#     'Date': pd.date_range(start=start_date, end=end_date, freq='D'),
#     'Price': np.random.uniform(90, 110, len(pd.date_range(start=start_date, end=end_date, freq='D')))
# })
#
# # Set the index to the 'Date' column
# df.set_index('Date', inplace=True)
#
# # Print the DataFrame
# print(df)
# ```
#
# This code generates a DataFrame with random stock prices for each day from January 2024 to June 2024. The 'Price' column is a random float between 90 and 110. The 'Date' column is a pandas DatetimeIndex with daily frequency.
#
# You can adjust the range of dates and the range of stock prices by modifying the `start_date`, `end_date`, and `start_date` and `end_date` parameters in the code.
#
# Note: This code generates a synthetic time series, which means it's not based on any real-world

# %% [markdown]
# ### Few-Shot Prompting

# %%
# Define initial messages
system_message = SystemMessage(content="You are a helpful assistant. Give an help in analysis")
user_message = HumanMessage(content=(
    "Classify the sentiment of a given text as Positive, Negative, or Neutral:\n"
    "Text: I love this product! It is amazing.\n"
    "Sentiment: Positive\n\n"
    "Text: This is the worst experience I have had.\n"
    "Sentiment: Negative\n\n"
    "Text: The movie was okay, not great but not bad either.\n"
    "Sentiment: Neutral\n\n"
    "Text: The service was fantastic and very fast.\n"
    "Sentiment: "
))

# Generate response
ai_response = generate_response(system_message, user_message,mode='shot')
print(ai_response.content)
# Out:
# The sentiment of the given text is Positive.

# %% [markdown]
# ### Chain-of-Thought prompting

# %%
# Define initial messages
system_message = SystemMessage(content="You are a helpful assistant. Give an help in analysis")
user_message = HumanMessage(content="Why does ice float on water? Think step-by-step, and explain why")


# Generate response
ai_response = generate_response(system_message, user_message, mode='chain-of-thought')
print(ai_response.content)
# Out:
# Let's break it down step-by-step:
#
# Step 1: Understand the properties of ice and water
# Ice is a solid state of water. Both ice and water are made up of water molecules. However, the arrangement of the molecules differs between the two states.
#
# Step 2: Compare the density of ice and water
# Density is the measure of how much mass is packed into a given volume. Density is measured in units of mass per unit volume, such as grams per cubic centimeter (g/cm³).
#
# Step 3: Determine the density of ice and water
# Ice has a density of approximately 0.92 g/cm³, while water has a density of approximately 1.00 g/cm³.
#
# Step 4: Explain why ice floats on water
# Since ice is less dense than water, it floats on top of the water. This is because the molecules in ice are arranged in a way that creates more space between them than in water. As a result, ice has a lower mass per unit volume than water.
#
# Step 5: Consider the role of temperature in the density of water
# As water freezes, the molecules arrange themselves in a crystalline structure with more space between them. This crystalline structure is less dense than the liquid water state.
#
# Step 6: Explain why ice floats on water at room temperature
# At room temperature, the density of water is still relatively high, but it's not as high as the density of ice. As a result, ice floats on top of water.
#
# In conclusion, ice floats on water because it is less dense than water. The arrangement of the molecules in ice creates more space between them, resulting in a lower mass per unit volume. This

# %% [markdown]
# ### Self-Consistency prompting

# %%
# Function to generate multiple responses for self-consistency
def generate_responses(system_message, user_message, n=5):
    responses = []

    for _ in range(n):
        # Construct the conversation text for chain-of-thought
        conversation = (f"{system_message}\n"
                        f"User: {user_message}\n"
                        f"AI: Let's break it down step-by-step:\n")

        # Tokenize input and create attention mask
        tokens = tokenizer(conversation, return_tensors="pt")
        inputs = tokens['input_ids'].to(device)
        attention_mask = tokens['attention_mask'].to(device)

        # Generate AI's response using chain-of-thought settings
        outputs = model.generate(inputs,
                                 attention_mask=attention_mask,
                                 max_new_tokens=350,
                                 temperature=0.3,
                                 top_p=0.9,
                                 do_sample=True)

        # Decode and collect the response
        output_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
        response_text = output_text.split('AI:')[-1].strip()
        responses.append(response_text)

    return responses

# %%
# Define initial messages (adapted to strings since schema is not used here)
system_message_content = "You are a helpful assistant. Give an help in analysis"
user_message_content = "Why does ice float on water? Think step-by-step, and explain why."

# Generate multiple responses for self-consistency
results = generate_responses(system_message_content, user_message_content, n=5)
for i, result in enumerate(results):
    print(f"Response {i+1}:\n{result}\n")
# Out:
# Response 1:
# Let's break it down step-by-step:
# 1. Ice is formed when water freezes.
# 2. When water freezes, it expands.
# 3. The expansion of water when it freezes causes it to be less dense than the water it was before freezing.
# 4. As a result, ice is less dense than water, which is why it floats on water.
# 5. This unique property of ice is crucial for life on Earth, as it allows ice to float on the surface of lakes and oceans during the winter, providing a habitat for aquatic life to survive.
#
# Response 2:
# Let's break it down step-by-step:
# 1. Ice is made up of water molecules that are arranged in a crystalline structure.
# 2. In this structure, the water molecules are arranged in a way that they are less dense than the surrounding water.
# 3. When ice forms, it expands and takes up more space than the same amount of water.
# 4. This expansion causes the ice to float on the surface of the water.
# 5. The reason for this is that the ice is less dense than the water, so it floats on top of the denser water.
# 6. This is why ice floats on water, and why it's important for aquatic life.
#
# Response 3:
# Let's break it down step-by-step:
# 1. Ice is made up of water molecules that are arranged in a crystalline structure.
# 2. When ice forms, the water molecules arrange themselves in a lattice-like structure with more hydrogen bonds between them.
# 3. The hydrogen bonds in ice are weaker than the covalent bonds between water molecules.
# 4. As the ice melts, the hydrogen bonds between water molecules break, and the molecules arrange themselves in a different structure.
# 5. In this new structure, the molecules are packed more tightly together, and the density increases.
# 6. Since the density of ice is less than that of water, ice floats on water.
#
# So, the reason why ice floats on water is due to the unique arrangement of water molecules in ice and the weaker hydrogen bonds between them compared to covalent bonds.
#
# Response 4:
# Let's break it down step-by-step:
# 1. Ice is made up of water molecules that are arranged in a crystalline structure.
# 2. When water freezes, the water molecules arrange themselves in a crystalline structure with the hydrogen bonds between them.
# 3. In this crystalline structure, the molecules are arranged in a way that the hydrogen bonds between them are stronger than the bonds between the molecules themselves.
# 4. As a result, the ice has a lower density than the liquid water.
# 5. Density is the mass per unit volume of a substance.
# 6. The mass of ice is less than the mass of liquid water because the hydrogen bonds between the molecules are stronger than the bonds between the molecules themselves.
# 7. Therefore, the density of ice is less than the density of liquid water.
# 8. As a result, ice floats on water.
# 9. The reason for this is that the ice is less dense than the liquid water.
# 10. This is why ice floats on water.
#
# Response 5:
# Let's break it down step-by-step:
# 1. Ice is made up of water molecules.
# 2. Water molecules are polar, meaning they have a slightly positive charge on one end and a slightly negative charge on the other.
# 3. When ice forms, the water molecules arrange themselves in a crystalline structure with the positive end of one molecule pointing towards the negative end of another molecule.
# 4. In this arrangement, the water molecules are able to form hydrogen bonds with each other.
# 5. Hydrogen bonds are weak bonds that form between the positive and negative ends of the molecules.
# 6. These hydrogen bonds allow the ice to be less dense than water.
# 7. Density is the mass of a substance per unit volume.
# 8. When ice forms, it is less dense than water because the hydrogen bonds cause the ice to be less compact than the liquid water.
# 9. As a result, ice floats on water.
# 10. This is why ice floats on water.

# %%
def get_most_common_response(responses):
    # Count the frequency of each response
    response_counts = collections.Counter(responses)
    # Get the most common response
    most_common_response, frequency = response_counts.most_common(1)[0]
    return most_common_response

# %%
# Find and print the most common response
most_common_response = get_most_common_response(results)
print(f"The most common response is:\n{most_common_response}")
# Out:
# The most common response is:
# Let's break it down step-by-step:
# 1. Ice is formed when water freezes.
# 2. When water freezes, it expands.
# 3. The expansion of water when it freezes causes it to be less dense than the water it was before freezing.
# 4. As a result, ice is less dense than water, which is why it floats on water.
# 5. This unique property of ice is crucial for life on Earth, as it allows ice to float on the surface of lakes and oceans during the winter, providing a habitat for aquatic life to survive.

# %% [markdown]
# ### Tree-of-Thought prompting

# %%
# Function to generate tree-of-thought responses
def generate_tree_of_thought_responses(system_message, user_message, depth=2, breadth=3):
    initial_conversation = (f"{system_message}\n"
                            f"User: {user_message}\n"
                            f"AI: Let's explore different possibilities:\n")
    tree = [{"text": initial_conversation, "depth": 0}]
    all_responses = []

    while tree:
        node = tree.pop(0)
        if node["depth"] < depth:
            tokens = tokenizer(node["text"], return_tensors="pt")
            inputs = tokens['input_ids'].to(device)
            attention_mask = tokens['attention_mask'].to(device)

            outputs = model.generate(inputs,
                                     attention_mask=attention_mask,
                                     max_new_tokens=350,
                                     temperature=0.3,
                                     top_p=0.9,
                                     do_sample=True,
                                     num_return_sequences=breadth)

            for output in outputs:
                output_text = tokenizer.decode(output, skip_special_tokens=True)
                response_text = output_text.split('AI:')[-1].strip()
                all_responses.append(response_text)

                # Create new branches
                tree.append({"text": node['text'] + response_text + "\nAI: Let's consider another possibility:", "depth": node['depth'] + 1})

    return all_responses

# %%
# Define initial messages
system_message_content = "You are a helpful assistant. Give an help in analysis"
user_message_content = "Why does ice float on water? Think of various possibilities and concepts."

# Generate tree-of-thought responses
results = generate_tree_of_thought_responses(system_message_content, user_message_content)
for i, result in enumerate(results):
    print(f"Branch {i+1}:\n{result}\n")
# Out:
# Branch 1:
# Let's explore different possibilities:
# 1. Density: Ice is less dense than water. This is because ice is made up of 92% water molecules arranged in a crystalline structure with a lower density than the liquid water.
# 2. Temperature: Ice is formed at a lower temperature than water. When ice forms, it expands and takes up more space than the liquid water. This expansion causes it to float on the surface of the water.
# 3. Pressure: The pressure of the water above the ice can cause the ice to melt. This is because the pressure increases with depth, and ice at the bottom of a body of water is subjected to higher pressure than ice at the surface.
# 4. Chemical composition: Ice is composed of hydrogen bonds between water molecules, which are stronger than the bonds between water molecules in liquid water. This results in ice being less dense than liquid water.
# 5. Boiling point: Water has a higher boiling point than ice. When ice melts, it turns into liquid water, which has a lower boiling point than ice. This is why ice floats on water.
# 6. Melting point: Ice melts at 0°C (32°F), which is lower than the boiling point of water (100°C or 212°F). This is why ice floats on water.
# 7. Surface tension: Ice has a lower surface tension than liquid water. This means that ice is less likely to sink to the bottom of a body of water.
# 8. Viscosity: Ice is less viscous than liquid water. This means that ice is less dense than liquid water.
# 9. Density of ice: Ice is less dense than liquid water. This is because ice is made up of
#
# Branch 2:
# Let's explore different possibilities:
# 1. Density: Ice is less dense than water. Density is the mass per unit volume of a substance. Ice has a lower density than water because its molecules are arranged in a crystalline structure that is less compact than the liquid water molecules. This arrangement allows the ice to float on the surface of the water.
#
# 2. Boiling and freezing points: Water has a unique property where its boiling point is higher than its freezing point. This means that ice floats on water because the ice is less dense than the water.
#
# 3. Surface tension: Water has a high surface tension due to the hydrogen bonds between its molecules. This surface tension causes water to behave in certain ways, such as forming droplets or spreading out on a surface. Ice also has a high surface tension, which allows it to float on water.
#
# 4. Viscosity: Viscosity is the measure of a fluid's resistance to flow. Water is a relatively viscous liquid, which means it resists flowing easily. Ice, on the other hand, is less viscous, which allows it to flow more easily. This difference in viscosity contributes to ice floating on water.
#
# 5. Pressure: When ice is submerged in water, it compresses the surrounding water. This compression reduces the pressure on the ice, allowing it to float. The pressure difference between the top and bottom of the ice is what allows it to float.
#
# 6. Chemical composition: Ice is composed of water molecules arranged in a crystalline structure. This structure is less compact than the liquid water molecules, which allows the ice to float on water.
#
# 7. Temperature: Ice is less dense than water because the arrangement of its molecules is less compact. As the temperature of the ice decreases, the molecules arrange themselves in a crystalline
#
# Branch 3:
# Let's explore different possibilities:
#
# Ice floats on water due to the unique properties of water molecules. Water is a polar molecule, meaning it has a slightly positive charge on one end and a slightly negative charge on the other. This polarity allows water molecules to form hydrogen bonds with each other.
#
# When ice forms, the water molecules arrange themselves in a crystalline structure with a repeating pattern of hydrogen bonds. This structure is less dense than the liquid water, which is why ice floats on water.
#
# Here are some possible explanations:
#
# 1. Hydrogen bonding: The hydrogen bonds between water molecules create a lattice structure that is less dense than the liquid water. This is because the hydrogen bonds are weaker than the bonds between the water molecules in the liquid state.
#
# 2. Density of water: The density of liquid water is higher than the density of ice. This means that ice is less dense than the surrounding liquid water.
#
# 3. Melting point: The melting point of ice is lower than the boiling point of water. This means that ice can melt into liquid water at temperatures below 0°C (32°F), which is the freezing point of water.
#
# 4. Cohesion: Water molecules have a strong tendency to stick together, which is known as cohesion. This cohesion allows water to form a solid (ice) that is less dense than the liquid water.
#
# In summary, ice floats on water due to the unique properties of water molecules, such as polarity and hydrogen bonding, which create a crystalline structure with a lower density than the liquid water.
#
# Branch 4:
# Let's consider another possibility:
# Another possibility is that ice floats on water due to the unique properties of water itself. Water is a polar molecule, which means that it has a slightly positive charge on one end and a slightly negative charge on the other end. This polarity allows water molecules to form hydrogen bonds with each other, which is what gives water its unique properties.
# In the case of ice, the hydrogen bonds between water molecules are weaker than the bonds between water molecules in liquid water. This means that ice is less dense than liquid water. Additionally, the arrangement of water molecules in ice is more open than in liquid water, which also contributes to its lower density.
# So, in summary, ice floats on water due to a combination of factors, including its lower density, unique properties of water, and the arrangement of water molecules in ice.
#
# Branch 5:
# Let's consider another possibility:
# 10. Density of ice: Ice is less dense than liquid water. This is because ice is made up of 92% water molecules arranged in a crystalline structure with a lower density than the liquid water.
#
# In conclusion, ice floats on water due to its lower density, lower boiling point, and lower surface tension than liquid water.
#
# Branch 6:
# Let's consider another possibility:
# 10. Density of ice: Ice is less dense than liquid water. This is because ice is made up of 92% water molecules arranged in a crystalline structure with a lower density than the liquid water.
#
# In conclusion, ice floats on water due to its lower density than water, which is caused by the arrangement of water molecules in a crystalline structure and the hydrogen bonds between them.
#
# Branch 7:
# Let's consider another possibility:
#
# Another possibility is that ice floats on water due to the unique properties of water itself. Water is a polar molecule, meaning that it has a slightly positive charge on one end and a slightly negative charge on the other. This polarity allows water molecules to form hydrogen bonds with each other, which is what gives water its unique properties.
#
# In the case of ice, the hydrogen bonds between the water molecules are weaker than the bonds between the water molecules in liquid water. This means that the ice is less dense than liquid water. Additionally, the arrangement of the water molecules in ice is less compact than in liquid water, which also contributes to the lower density of ice.
#
# So, in summary, ice floats on water due to a combination of factors, including its lower density, unique chemical composition, and the properties of water itself.
#
# Branch 8:
# Let's consider another possibility:
# Another possibility is that ice floats on water due to the unique properties of water itself. Water has a high specific heat capacity, which means it can absorb and release a large amount of heat energy without a significant change in temperature. This property allows water to remain liquid at temperatures below 0°C (32°F), even in the presence of ice.
#
# Additionally, water has a high latent heat of vaporization, which means it requires a lot of energy to change from a liquid to a gas. This property allows water to remain in a liquid state even when it is cooled to its freezing point.
#
# The combination of these properties allows water to remain liquid at temperatures below 0°C (32°F), which is why ice can float on its surface.
#
# Branch 9:
# Let's consider another possibility:
#
# Another possibility is that ice floats on water due to the unique properties of water itself. Water has a high specific heat capacity, which means it can absorb and release a large amount of heat energy without a significant change in temperature. This property allows water to remain liquid even at very low temperatures.
#
# Additionally, water has a high latent heat of vaporization, which means it requires a lot of energy to change from a liquid to a gas. This property allows water to remain in its liquid state even when it is heated to high temperatures.
#
# The combination of these properties allows water to remain liquid even when it is cooled to its freezing point, which is why ice floats on water.
#
# Branch 10:
# Let's consider another possibility:
#
# Another possibility is that ice floats on water due to the specific arrangement of water molecules in the ice crystal lattice. The hydrogen bonds between water molecules in the ice crystal lattice are arranged in a way that creates a structure with a lower density than the liquid water.
#
# This arrangement of hydrogen bonds in the ice crystal lattice is responsible for the lower density of ice compared to liquid water. The hydrogen bonds between water molecules in the ice crystal lattice are weaker than the bonds between the water molecules in the liquid state, which contributes to the lower density of ice.
#
# In summary, the unique arrangement of water molecules in the ice crystal lattice, including the hydrogen bonds and the crystalline structure, is responsible for the lower density of ice compared to liquid water.
#
# Branch 11:
# Let's consider another possibility:
#
# Another possibility is that the density of ice is lower than that of liquid water due to the arrangement of water molecules. In liquid water, the water molecules are randomly arranged, but in ice, they form a crystalline structure with a repeating pattern of hydrogen bonds. This arrangement allows the ice to be less dense than the liquid water.
#
# Here are some possible explanations:
#
# 1. Arrangement of water molecules: The arrangement of water molecules in ice is different from that in liquid water. In liquid water, the molecules are randomly arranged, but in ice, they form a crystalline structure with a repeating pattern of hydrogen bonds.
#
# 2. Lower density: The crystalline structure of ice has a lower density than the liquid water. This is because the hydrogen bonds between the water molecules are weaker than the bonds between the water molecules in the liquid state.
#
# 3. Cohesion: Water molecules have a strong tendency to stick together, which is known as cohesion. This cohesion allows water to form a solid (ice) that is less dense than the liquid water.
#
# In summary, the density of ice is lower than that of liquid water due to the arrangement of water molecules in ice, which is a crystalline structure with a repeating pattern of hydrogen bonds. This arrangement allows the ice to be less dense than the liquid water.
#
# Branch 12:
# Let's consider another possibility:
#
# Another possibility is that ice floats on water due to the specific arrangement of water molecules in the ice crystal lattice. In ice, the water molecules are arranged in a crystalline structure with a repeating pattern of hydrogen bonds. This arrangement is less dense than the liquid water, which is why ice floats on water.
#
# Here are some possible explanations:
#
# 1. Hydrogen bonding: The hydrogen bonds between water molecules create a lattice structure that is less dense than the liquid water. This is because the hydrogen bonds are weaker than the bonds between the water molecules in the liquid state.
#
# 2. Crystal structure: The crystal structure of ice is less dense than the liquid water. This is because the arrangement of water molecules in the ice crystal lattice is less dense than the liquid water.
#
# 3. Cohesion: Water molecules have a strong tendency to stick together, which is known as cohesion. This cohesion allows water to form a solid (ice) that is less dense than the liquid water.
#
# In summary, ice floats on water due to the unique properties of water molecules, such as polarity and hydrogen bonding, which create a crystalline structure with a lower density than the liquid water.

# %%
def score_branches(branches, user_query, reference_embeddings, model_embeddings):
    # Create a list to hold branch scores
    scored_branches = []

    # Embed the user query
    query_embedding = model_embeddings(user_query)

    for branch in branches:
        # Embed the branch
        branch_embedding = model_embeddings(branch)

        # Calculate similarity with the user query
        similarity_score = cosine_similarity([query_embedding], [branch_embedding])[0][0]

        # I'll use just the similarity score
        scored_branches.append((branch, similarity_score))

    # Sort branches by score
    scored_branches.sort(key=lambda x: x[1], reverse=True)

    return scored_branches

# function to get embeddings from a model (easiest approach used for exercise)
def model_embeddings(text):
    return np.random.rand(1000)

# Scoring branches
scored_results = score_branches(results, user_message_content, model_embeddings, model_embeddings)
best_branch = scored_results[0][0]  # Select the branch with the highest score
print(f"The best branch is:\n{best_branch}")
# Out:
# The best branch is:
# Let's consider another possibility:
# Another possibility is that ice floats on water due to the unique properties of water itself. Water has a high specific heat capacity, which means it can absorb and release a large amount of heat energy without a significant change in temperature. This property allows water to remain liquid at temperatures below 0°C (32°F), even in the presence of ice.
#
# Additionally, water has a high latent heat of vaporization, which means it requires a lot of energy to change from a liquid to a gas. This property allows water to remain in a liquid state even when it is cooled to its freezing point.
#
# The combination of these properties allows water to remain liquid at temperatures below 0°C (32°F), which is why ice can float on its surface.
